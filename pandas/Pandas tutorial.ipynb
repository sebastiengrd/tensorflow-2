# %% [markdown]
# Panda tutorial from Corey Schafer : https://www.youtube.com/watch?v=ZyhVh-qRZPA&list=PL-osiE80TeTsWmV9i9c58mdDCSskIFdDS

# %%
import pandas as pd

# %%
df = pd.read_csv('data/Sample100.csv')

# %%
df
# Out:
#     Serial Number                   Company Name  Employee Markme  \
# 0   9788189999599                 TALES OF SHIVA             Mark
# 1   9780099578079      1Q84 THE COMPLETE TRILOGY  HARUKI MURAKAMI
# 2   9780198082897                       MY KUMAN             Mark
# 3   9780007880331        THE GOD OF SMAAL THINGS    ARUNDHATI ROY
# 4   9780545060455               THE BLACK CIRCLE             Mark
# ..            ...                            ...              ...
# 94  9788184821536  MORE STORIES FROM THE JATAKAS             Mark
# 95  9788184821543           MORE TALES OF BIRBAL                -
# 96  9788184821550         TALES FROM THE JATAKAS                -
# 97  9788184821567               RAMarkS OF MEWAR                -
# 98  9788184821574       THE SONS OF THE PANDAVAS                -
#
#            Description  Leave
# 0                 mark      0
# 1                 Mark      0
# 2                 Mark      0
# 3   4TH HARPER COLLINS      2
# ...

# %%
df.shape
# Out:
# (99, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Serial Number    99 non-null     int64
#  1   Company Name     99 non-null     object
#  2   Employee Markme  97 non-null     object
#  3   Description      99 non-null     object
#  4   Leave            99 non-null     int64
# dtypes: int64(2), object(3)
# memory usage: 4.0+ KB

# %%
df.head(7)
# Out:
#    Serial Number                   Company Name  Employee Markme  \
# 0  9788189999599                 TALES OF SHIVA             Mark
# 1  9780099578079      1Q84 THE COMPLETE TRILOGY  HARUKI MURAKAMI
# 2  9780198082897                       MY KUMAN             Mark
# 3  9780007880331        THE GOD OF SMAAL THINGS    ARUNDHATI ROY
# 4  9780545060455               THE BLACK CIRCLE             Mark
# 5  9788126525072  THE THREE LAWS OF PERFORMANCE             Mark
# 6  9789381626610              CHAMarkKYA MANTRA             Mark
#
#           Description  Leave
# 0                mark      0
# 1                Mark      0
# 2                Mark      0
# 3  4TH HARPER COLLINS      2
# 4  4TH HARPER COLLINS      0
# 5  4TH HARPER COLLINS      0
# 6  4TH HARPER COLLINS      0

# %%
df.tail(9)
# Out:
#     Serial Number                   Company Name Employee Markme Description  \
# 90  9788184824018     THE GREAT MUGHALS {5-IN-1}        AMarkNT.         ACK
# 91  9788184824049              FAMOUS SCIENTISTS            Mark         ACK
# 92  9788184825978                       KOMarkRK            Mark         ACK
# 93  9788184826098               THE MUGHAL COURT         REEMark         ACK
# 94  9788184821536  MORE STORIES FROM THE JATAKAS            Mark         ACK
# 95  9788184821543           MORE TALES OF BIRBAL               -         ACK
# 96  9788184821550         TALES FROM THE JATAKAS               -         ACK
# 97  9788184821567               RAMarkS OF MEWAR               -         ACK
# 98  9788184821574       THE SONS OF THE PANDAVAS               -         ACK
#
#     Leave
# 90      0
# 91      0
# 92      0
# 93      0
# 94      0
# 95      0
# 96      0
# 97      0
# 98      0

# %% [markdown]
# # Make csv from a dictionnary

# %%
people = {
    'first' : ['a', 'b', 'c', 'c'],
    'last' : ['i', 'j', 'k', 'e'],
    'email' : ['i@email.com', 'j@email.com', 'k@email.com', 'e@email.com']
}

df = pd.DataFrame(people)

# %%
df
# Out:
#   first last        email
# 0     a    i  i@email.com
# 1     b    j  j@email.com
# 2     c    k  k@email.com
# 3     c    e  e@email.com

# %%
df.email
# Out:
# 0    i@email.com
# 1    j@email.com
# 2    k@email.com
# 3    e@email.com
# Name: email, dtype: object

# %%
df['email']
# Out:
# 0    i@email.com
# 1    j@email.com
# 2    k@email.com
# 3    e@email.com
# Name: email, dtype: object

# %%
type(df['email'])
# Out:
# pandas.core.series.Series

# %%
df[['last', 'email']]
# Out:
#   last        email
# 0    i  i@email.com
# 1    j  j@email.com
# 2    k  k@email.com
# 3    e  e@email.com

# %%
df.columns
# Out:
# Index(['first', 'last', 'email'], dtype='object')

# %%
df.iloc[0] #integer location : 0,1,2,3,...
# Out:
# first              a
# last               i
# email    i@email.com
# Name: 0, dtype: object

# %%
df.iloc[[0,1]]
# Out:
#   first last        email
# 0     a    i  i@email.com
# 1     b    j  j@email.com

# %%
df.iloc[[0,1],2]
# Out:
# 0    i@email.com
# 1    j@email.com
# Name: email, dtype: object

# %%
df.loc[[0,1], ['last', 'email']]
# Out:
#   last        email
# 0    i  i@email.com
# 1    j  j@email.com

# %%
df = pd.read_csv('data/Sample100.csv')

# %%
df.shape
# Out:
# (99, 5)

# %%
df
# Out:
#     Serial Number                   Company Name  Employee Markme  \
# 0   9788189999599                 TALES OF SHIVA             Mark
# 1   9780099578079      1Q84 THE COMPLETE TRILOGY  HARUKI MURAKAMI
# 2   9780198082897                       MY KUMAN             Mark
# 3   9780007880331        THE GOD OF SMAAL THINGS    ARUNDHATI ROY
# 4   9780545060455               THE BLACK CIRCLE             Mark
# ..            ...                            ...              ...
# 94  9788184821536  MORE STORIES FROM THE JATAKAS             Mark
# 95  9788184821543           MORE TALES OF BIRBAL                -
# 96  9788184821550         TALES FROM THE JATAKAS                -
# 97  9788184821567               RAMarkS OF MEWAR                -
# 98  9788184821574       THE SONS OF THE PANDAVAS                -
#
#            Description  Leave
# 0                 mark      0
# 1                 Mark      0
# 2                 Mark      0
# 3   4TH HARPER COLLINS      2
# ...

# %%
df['Leave'].value_counts()
# Out:
# 0     74
# 1     13
# 10     4
# 4      3
# 2      3
# 5      2
# Name: Leave, dtype: int64

# %%
df.loc[10:20, 'Company Name':'Description']
# Out:
#                                          Company Name Employee Markme  \
# 10                          DONGRI SE DUBAI TAK (MPH)            Mark
# 11                              MarkLANDA ADYTAN KOSH            Mark
# 12                       MarkLANDA VISHAL SHABD SAGAR               -
# 13               MarkLANDA CONCISE DICT(ENG TO HINDI)            Mark
# 14  LIEUTEMarkMarkT GENERAL BHAGAT: A SAGA OF BRAV...            Mark
# 15                            LN. MarkIK SUNDER SINGH             N.A
# 16                                     I AM KRISHMark    DEEP TRIVEDI
# 17                     DON'T TEACH ME TOLERANCE INDIA    DEEP TRIVEDI
# 18                 MUJHE SAHISHNUTA MAT SIKHAO BHARAT    DEEP TRIVEDI
# 19                                 SECRETS OF DESTINY    DEEP TRIVEDI
# 20        BHAGYA KE RAHASYA (HINDI) SECRET OF DESTINY    DEEP TRIVEDI
#
#                    Description
# 10             A & A PUBLISHER
# 11           AADISH BOOK DEPOT
# ...

# %%
df.set_index('Serial Number')
# Out:
#                                 Company Name  Employee Markme  \
# Serial Number
# 9788189999599                 TALES OF SHIVA             Mark
# 9780099578079      1Q84 THE COMPLETE TRILOGY  HARUKI MURAKAMI
# 9780198082897                       MY KUMAN             Mark
# 9780007880331        THE GOD OF SMAAL THINGS    ARUNDHATI ROY
# 9780545060455               THE BLACK CIRCLE             Mark
# ...                                      ...              ...
# 9788184821536  MORE STORIES FROM THE JATAKAS             Mark
# 9788184821543           MORE TALES OF BIRBAL                -
# 9788184821550         TALES FROM THE JATAKAS                -
# 9788184821567               RAMarkS OF MEWAR                -
# 9788184821574       THE SONS OF THE PANDAVAS                -
#
#                       Description  Leave
# Serial Number
# 9788189999599                mark      0
# 9780099578079                Mark      0
# 9780198082897                Mark      0
# ...

# %%
df
# Out:
#     Serial Number                   Company Name  Employee Markme  \
# 0   9788189999599                 TALES OF SHIVA             Mark
# 1   9780099578079      1Q84 THE COMPLETE TRILOGY  HARUKI MURAKAMI
# 2   9780198082897                       MY KUMAN             Mark
# 3   9780007880331        THE GOD OF SMAAL THINGS    ARUNDHATI ROY
# 4   9780545060455               THE BLACK CIRCLE             Mark
# ..            ...                            ...              ...
# 94  9788184821536  MORE STORIES FROM THE JATAKAS             Mark
# 95  9788184821543           MORE TALES OF BIRBAL                -
# 96  9788184821550         TALES FROM THE JATAKAS                -
# 97  9788184821567               RAMarkS OF MEWAR                -
# 98  9788184821574       THE SONS OF THE PANDAVAS                -
#
#            Description  Leave
# 0                 mark      0
# 1                 Mark      0
# 2                 Mark      0
# 3   4TH HARPER COLLINS      2
# ...

# %%
df.set_index('Serial Number', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-48-741c3b5fab6e> in <module>
# ----> 1 df.set_index('Serial Number', inplace=True)
#
# ~/Documents/tensorflow-2/tf2env/lib/python3.6/site-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4301
#    4302         if missing:
# -> 4303             raise KeyError(f"None of {missing} are in the columns")
#    4304
#    4305         if inplace:
#
# KeyError: "None of ['Serial Number'] are in the columns"

# %%
df
# Out:
#                                 Company Name  Employee Markme  \
# Serial Number
# 9788189999599                 TALES OF SHIVA             Mark
# 9780099578079      1Q84 THE COMPLETE TRILOGY  HARUKI MURAKAMI
# 9780198082897                       MY KUMAN             Mark
# 9780007880331        THE GOD OF SMAAL THINGS    ARUNDHATI ROY
# 9780545060455               THE BLACK CIRCLE             Mark
# ...                                      ...              ...
# 9788184821536  MORE STORIES FROM THE JATAKAS             Mark
# 9788184821543           MORE TALES OF BIRBAL                -
# 9788184821550         TALES FROM THE JATAKAS                -
# 9788184821567               RAMarkS OF MEWAR                -
# 9788184821574       THE SONS OF THE PANDAVAS                -
#
#                       Description  Leave
# Serial Number
# 9788189999599                mark      0
# 9780099578079                Mark      0
# 9780198082897                Mark      0
# ...

# %%
df.loc[9788189999599:9780545060455]
# Out:
#                             Company Name  Employee Markme         Description  \
# Serial Number
# 9788189999599             TALES OF SHIVA             Mark                mark
# 9780099578079  1Q84 THE COMPLETE TRILOGY  HARUKI MURAKAMI                Mark
# 9780198082897                   MY KUMAN             Mark                Mark
# 9780007880331    THE GOD OF SMAAL THINGS    ARUNDHATI ROY  4TH HARPER COLLINS
# 9780545060455           THE BLACK CIRCLE             Mark  4TH HARPER COLLINS
#
#                Leave
# Serial Number
# 9788189999599      0
# 9780099578079      0
# 9780198082897      0
# 9780007880331      2
# 9780545060455      0

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#     index  Serial Number                   Company Name  Employee Markme  \
# 0       0  9788189999599                 TALES OF SHIVA             Mark
# 1       1  9780099578079      1Q84 THE COMPLETE TRILOGY  HARUKI MURAKAMI
# 2       2  9780198082897                       MY KUMAN             Mark
# 3       3  9780007880331        THE GOD OF SMAAL THINGS    ARUNDHATI ROY
# 4       4  9780545060455               THE BLACK CIRCLE             Mark
# ..    ...            ...                            ...              ...
# 94     94  9788184821536  MORE STORIES FROM THE JATAKAS             Mark
# 95     95  9788184821543           MORE TALES OF BIRBAL                -
# 96     96  9788184821550         TALES FROM THE JATAKAS                -
# 97     97  9788184821567               RAMarkS OF MEWAR                -
# 98     98  9788184821574       THE SONS OF THE PANDAVAS                -
#
#            Description  Leave
# 0                 mark      0
# ...

# %% [markdown]
# If we want to directly load the dataframe with the Serial Number as the index

# %%
df = pd.read_csv('data/Sample100.csv', index_col='Serial Number')

# %%
df
# Out:
#                                 Company Name  Employee Markme  \
# Serial Number
# 9788189999599                 TALES OF SHIVA             Mark
# 9780099578079      1Q84 THE COMPLETE TRILOGY  HARUKI MURAKAMI
# 9780198082897                       MY KUMAN             Mark
# 9780007880331        THE GOD OF SMAAL THINGS    ARUNDHATI ROY
# 9780545060455               THE BLACK CIRCLE             Mark
# ...                                      ...              ...
# 9788184821536  MORE STORIES FROM THE JATAKAS             Mark
# 9788184821543           MORE TALES OF BIRBAL                -
# 9788184821550         TALES FROM THE JATAKAS                -
# 9788184821567               RAMarkS OF MEWAR                -
# 9788184821574       THE SONS OF THE PANDAVAS                -
#
#                       Description  Leave
# Serial Number
# 9788189999599                mark      0
# 9780099578079                Mark      0
# 9780198082897                Mark      0
# ...

# %%
schema = {
    "Column" : ['Compagny Name', 'Employee MarkMe', 'Description', 'Leave'],
    "Description" : ['Name of the compagny', 'Name of the employee', 'More info', 'Nbr of people that left']
}

schema_df = pd.DataFrame(schema)

# %%
schema_df
# Out:
#                              Description
# Column
# Compagny Name       Name of the compagny
# Employee MarkMe     Name of the employee
# Description                    More info
# Leave            Nbr of people that left

# %%
schema_df.set_index('Column', inplace=True)

# %%
schema_df.loc['Leave', 'Description']
# Out:
# 'Nbr of people that left'

# %%
schema_df.sort_index(ascending=True, inplace=True)

# %%
schema_df
# Out:
#                              Description
# Column
# Compagny Name       Name of the compagny
# Description                    More info
# Employee MarkMe     Name of the employee
# Leave            Nbr of people that left

# %%
filt = (df['Employee Markme'] == 'Mark')

# %%
df[filt]
# Out:
#                                                     Company Name  \
# Serial Number
# 9788189999599                                     TALES OF SHIVA
# 9780198082897                                           MY KUMAN
# 9780545060455                                   THE BLACK CIRCLE
# 9788126525072                      THE THREE LAWS OF PERFORMANCE
# 9789381626610                                  CHAMarkKYA MANTRA
# 9788184513523                                           59.FLAGS
# 9780743234801                THE POWER OF POSITIVE THINKING FROM
# 9788183223966                          DONGRI SE DUBAI TAK (MPH)
# 9788187776005                              MarkLANDA ADYTAN KOSH
# 8187776021                  MarkLANDA CONCISE DICT(ENG TO HINDI)
# 9789384716165  LIEUTEMarkMarkT GENERAL BHAGAT: A SAGA OF BRAV...
# 9788188440061           QUESTIONS & ANWERS ABOUT THE GREAT BIBLE
# 9789382088189               NIBANDH EVAM KAHANI LEKHAN { HINDI }
# ...

# %%
df.loc[filt, 'Leave']
# Out:
# Serial Number
# 9788189999599    0
# 9780198082897    0
# 9780545060455    0
# 9788126525072    0
# 9789381626610    0
# 9788184513523    0
# 9780743234801    0
# 9788183223966    0
# 9788187776005    0
# 8187776021       0
# 9789384716165    2
# 9788188440061    4
# 9789382088189    1
# 9789383454563    0
# 9789383454570    0
# 9789383454891    0
# 9788189999803    0
# 9788184820355    0
# 9788184820652    0
# 9788184822113    1
# 9788184825862    0
# 9788184823219    0
# 9788184825213    0
# 9788184824049    0
# 9788184825978    0
# 9788184821536    0
# Name: Leave, dtype: int64

# %%
filt1 = (df["Employee Markme"] == "Mark") & (df["Leave"] == 0)

# %%
df.loc[~filt1, 'Company Name']#tilta is not
# Out:
# Serial Number
# 9780099578079                            1Q84 THE COMPLETE TRILOGY
# 9780007880331                              THE GOD OF SMAAL THINGS
# 9789381529621                           YOU CAN IF YO THINK YO CAN
# 9788187776013                         MarkLANDA VISHAL SHABD SAGAR
# 9789384716165    LIEUTEMarkMarkT GENERAL BHAGAT: A SAGA OF BRAV...
#                                        ...
# 9788184826098                                     THE MUGHAL COURT
# 9788184821543                                 MORE TALES OF BIRBAL
# 9788184821550                               TALES FROM THE JATAKAS
# 9788184821567                                     RAMarkS OF MEWAR
# 9788184821574                             THE SONS OF THE PANDAVAS
# Name: Company Name, Length: 77, dtype: object
